# %%
import glob #importing glob library
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

# %%
import astropy
import astropy.units as u
from astropy.utils.data import download_file
from astropy.io import fits  # We use fits to open the actual data file
from astropy.utils import data
from astropy.wcs import wcs
from astropy.visualization import (AsinhStretch, LogStretch, 
                                  PercentileInterval, ImageNormalize, simple_norm, ZScaleInterval)

# %%
from astropy.nddata import CCDData
import pandas as pd

from astropy.coordinates import SkyCoord

import ipywidgets as widgets
# !pip install ipycanvas
from IPython.display import display
# Out:
# Requirement already satisfied: ipycanvas in c:\users\isaac\anaconda3\lib\site-packages (0.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\isaac\anaconda3\lib\site-packages (from ipycanvas) (8.1.7)
# Requirement already satisfied: numpy in c:\users\isaac\anaconda3\lib\site-packages (from ipycanvas) (2.3.5)
# Requirement already satisfied: pillow>=6.0 in c:\users\isaac\anaconda3\lib\site-packages (from ipycanvas) (12.0.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\isaac\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\isaac\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\isaac\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\isaac\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\isaac\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (3.0.15)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\isaac\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\isaac\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\isaac\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\isaac\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\isaac\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\isaac\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.2.3)

# %%
# !pip install astropy astroalign numpy
import astroalign as aa
# Out:
# Requirement already satisfied: astropy in c:\users\isaac\anaconda3\lib\site-packages (7.1.1)
# Requirement already satisfied: astroalign in c:\users\isaac\anaconda3\lib\site-packages (2.6.2)
# Requirement already satisfied: numpy in c:\users\isaac\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\isaac\anaconda3\lib\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in c:\users\isaac\anaconda3\lib\site-packages (from astropy) (0.2025.11.10.0.38.31)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\isaac\anaconda3\lib\site-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\isaac\anaconda3\lib\site-packages (from astropy) (25.0)
# Requirement already satisfied: scipy in c:\users\isaac\anaconda3\lib\site-packages (from astroalign) (1.16.3)
# Requirement already satisfied: scikit-image in c:\users\isaac\anaconda3\lib\site-packages (from astroalign) (0.25.2)
# Requirement already satisfied: sep>=1.4.0 in c:\users\isaac\anaconda3\lib\site-packages (from astroalign) (1.4.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\isaac\anaconda3\lib\site-packages (from scikit-image->astroalign) (3.5)
# Requirement already satisfied: pillow>=10.1 in c:\users\isaac\anaconda3\lib\site-packages (from scikit-image->astroalign) (12.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\isaac\anaconda3\lib\site-packages (from scikit-image->astroalign) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\isaac\anaconda3\lib\site-packages (from scikit-image->astroalign) (2025.10.4)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\isaac\anaconda3\lib\site-packages (from scikit-image->astroalign) (0.4)

# %%
from ipycanvas import Canvas
from PIL import Image
from PIL import ImageTk
from tkinter import *

# %%
flat_image_data_1 = fits.getdata('C:/Users/isaac/Downloads/flat_fits_1.fits')
plt.figure(figsize=(16, 16))
image_data = np.nan_to_num(fits.open('C:/Users/isaac/Downloads/flat_fits_1.fits')[0].data)
interval =ZScaleInterval(n_samples=1000, contrast=0.25)
vmin,vmax = interval.get_limits(image_data)

if vmax <= vmin or (vmax - vmin) < 1e-5:
    interval = PercentileInterval(99.999)
    vmin, vmax = interval.get_limits(image_data)

data_range = vmax - vmin
vmin_adjusted = vmin +(data_range * 0.18)

clipped_image_data = np.clip(image_data, vmin_adjusted, vmax)
normalized = (clipped_image_data - vmin_adjusted) / (vmax - vmin_adjusted)
canvas_image = (normalized * 255).astype(np.uint8)

# %%
from PIL import Image

root = Tk()
root.title("Pick Star")
root.geometry('900x700')

pil_img = Image.fromarray(canvas_image, mode='L')
tk_img = ImageTk.PhotoImage(image=pil_img, master=root)

hbar = Scrollbar(root, orient=HORIZONTAL)
hbar.pack(side=BOTTOM, fill=X)
vbar = Scrollbar(root, orient=VERTICAL)
vbar.pack(side=RIGHT, fill=Y)

canvas = Canvas(root, width=800, height=600,
                scrollregion=(0, 0, canvas_image.shape[1], canvas_image.shape[0]),
                xscrollcommand=hbar.set, yscrollcommand=vbar.set)
canvas.pack(side=LEFT, expand=True, fill=BOTH)

hbar.config(command=canvas.xview)
vbar.config(command=canvas.yview)
canvas.create_image(0, 0, anchor="nw", image=tk_img)

chosen_x = [0]
chosen_y = [0]

def give_coords(event):
    true_x = int(canvas.canvasx(event.x))
    true_y = int(canvas.canvasy(event.y))
    height, width = canvas_image.shape
    
    if 0 <= true_x < width and 0 <= true_y < height:
        pixel_value = image_data[true_y, true_x]
        print(f"FITS Coord: ({true_x}, {true_y}) | Intensity: {pixel_value}       ", end="\r")
        chosen_x[0] = true_x
        chosen_y[0] = true_y

canvas.bind('<1>', give_coords)

root.protocol("WM_DELETE_WINDOW", lambda: (root.quit(), root.destroy()))
root.mainloop()
# Out:
# FITS Coord: (2047, 2047) | Intensity: 2940.888916015625

# %%
print(chosen_x)
print(chosen_y)
# Out:
# [2047]
# [2047]

# %%
img_aligned, footprint = aa.register(img, img_rotated, detection_sigma=3.0)
#img_aligned names the aligned image
#footprint is just what image_aligned will be
#aa.register is the acutal function that aligns
#aa.register(image that you match to, image that needs to be shifted, idk about detection I think that specifies how specific the matching al
